# %% [markdown]
# # SVM (Support Vector Machines) with cancer dataset

# %% [markdown]
# # 1. Import necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import preprocessing
from sklearn import svm
import itertools
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# # 2. Load the dataset

# %%
df=pd.read_csv("cell_samples.csv")

# %% [markdown]
# # 3. Visualize the dataset and preprocessing

# %%
df.head()
# Out:
#         ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0  1000025      5         1          1        1            2       1
# 1  1002945      5         4          4        5            7      10
# 2  1015425      3         1          1        1            2       2
# 3  1016277      6         8          8        1            3       4
# 4  1017023      4         1          1        3            2       1
#
#    BlandChrom  NormNucl  Mit  Class
# 0           3         1    1      2
# 1           3         2    1      2
# 2           3         1    1      2
# 3           3         7    1      2
# 4           3         1    1      2

# %% [markdown]
# ### We don't need the ID column so we will drop it.

# %%
df.drop("ID", axis=1, inplace= True)
df
# Out:
#      Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  BlandChrom  \
# 0        5         1          1        1            2       1           3
# 1        5         4          4        5            7      10           3
# 2        3         1          1        1            2       2           3
# 3        6         8          8        1            3       4           3
# 4        4         1          1        3            2       1           3
# ..     ...       ...        ...      ...          ...     ...         ...
# 694      3         1          1        1            3       2           1
# 695      2         1          1        1            2       1           1
# 696      5        10         10        3            7       3           8
# 697      4         8          6        4            3       4          10
# 698      4         8          8        5            4       5          10
#
#      NormNucl  Mit  Class
# 0           1    1      2
# ...

# %% [markdown]
# ### We need to figure out how many classes we have.

# %%
df['Class'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
df["Class"].value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %%
df["Class"].hist()

# %%
df.columns
# Out:
# Index(['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
#        'BlandChrom', 'NormNucl', 'Mit', 'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Clump           int64
# UnifSize        int64
# UnifShape       int64
# MargAdh         int64
# SingEpiSize     int64
# BareNuc        object
# BlandChrom      int64
# NormNucl        int64
# Mit             int64
# Class           int64
# dtype: object

# %%
df['BareNuc'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: BareNuc, dtype: int64

# %% [markdown]
# ### We need to convert the type of BareNuc from object to int64

# %%
df = df[pd.to_numeric(df['BareNuc'], errors='coerce').notnull()]
df['BareNuc'] = df['BareNuc'].astype('int64')
df.dtypes
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Clump          int64
# UnifSize       int64
# UnifShape      int64
# MargAdh        int64
# SingEpiSize    int64
# BareNuc        int64
# BlandChrom     int64
# NormNucl       int64
# Mit            int64
# Class          int64
# dtype: object

# %%
df['BareNuc'].value_counts()
# Out:
# 1     402
# 10    132
# 5      30
# 2      30
# 3      28
# 8      21
# 4      19
# 9       9
# 7       8
# 6       4
# Name: BareNuc, dtype: int64

# %%
df
# Out:
#      Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0        5         1          1        1            2        1           3
# 1        5         4          4        5            7       10           3
# 2        3         1          1        1            2        2           3
# 3        6         8          8        1            3        4           3
# 4        4         1          1        3            2        1           3
# ..     ...       ...        ...      ...          ...      ...         ...
# 694      3         1          1        1            3        2           1
# 695      2         1          1        1            2        1           1
# 696      5        10         10        3            7        3           8
# 697      4         8          6        4            3        4          10
# 698      4         8          8        5            4        5          10
#
#      NormNucl  Mit  Class
# 0           1    1      2
# ...

# %% [markdown]
# # 3. Plotting the dataframe

# %%
sns.pairplot(df, hue="Class", markers="o")
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### Plot the 50 points of dataframe based on X=Clump , Y=UnifSize

# %%
ax=df[df['Class']==4][0:50].plot(kind="scatter", x='Clump', y="UnifSize", color='DarkBlue', label='malignant');
df[df['Class']==2][0:50].plot(kind="scatter", x='Clump', y="UnifSize", color='Red', label='benign', ax=ax);
plt.show()

# %% [markdown]
# # 4. Train/Test Split

# %%
df.columns
# Out:
# Index(['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
#        'BlandChrom', 'NormNucl', 'Mit', 'Class'],
#       dtype='object')

# %%
features=df[['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
       'BlandChrom', 'NormNucl', 'Mit']]
X=np.asarray(features)
X[0:5]
# Out:
# array([[ 5,  1,  1,  1,  2,  1,  3,  1,  1],
#        [ 5,  4,  4,  5,  7, 10,  3,  2,  1],
#        [ 3,  1,  1,  1,  2,  2,  3,  1,  1],
#        [ 6,  8,  8,  1,  3,  4,  3,  7,  1],
#        [ 4,  1,  1,  3,  2,  1,  3,  1,  1]], dtype=int64)

# %%
df["Class"]=df["Class"].astype('int')
y=np.asarray(df["Class"])
y[0:5]
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array([2, 2, 2, 2, 2])

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=4)
print("Train set :", X_train.shape, y_train.shape)
print("Test set : ", X_test.shape, y_test.shape)
# Out:
# Train set : (546, 9) (546,)
# Test set :  (137, 9) (137,)

# %% [markdown]
# # 5. Modeling (SVM with Scikit-learn)

# %%
clf=svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
yhat=clf.predict(X_test)
print(y_test[0:5])
print(yhat[0:5])
# Out:
# [2 4 2 4 2]
# [2 4 2 4 2]

# %% [markdown]
# # 6. Evaluation

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.9639038982104676

# %%
from sklearn.metrics import jaccard_score
jaccard_score(y_test, yhat, pos_label=2)
# Out:
# 0.9444444444444444

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, yhat)
# Out:
# array([[85,  5],
#        [ 0, 47]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test, yhat), annot=True, cmap="YlGnBu")
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, yhat)
# Out:
# 0.9635036496350365
